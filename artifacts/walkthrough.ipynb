# %% [markdown]
# # Synthetic HW 4 walkthrough
# Synthetic cache example at now=10: edge expires; live and forever remain.
# These cells have not been executed. The PNG is a schematic, not a benchmark.

# %%
from solution import visible_entries
visible_entries({"edge": ("a", 10), "live": ("b", 12), "forever": ("c", None)}, 10)
